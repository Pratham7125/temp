# %%
from tensorflow.compat.v1.losses import sparse_softmax_cross_entropy
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
# Out:
# WARNING:tensorflow:From C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
mp_holistic = mp.solutions.holistic  # Holistic model
mp_drawing = mp.solutions.drawing_utils  # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False  # Image is no longer writeable
    results = model.process(image)  # Make prediction
    image.flags.writeable = True  # Image is now writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION)  # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)  # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)  # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)  # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                               mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                               mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
                               )
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                               mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
                               mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
                               )
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                               mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                               mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
                               )
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                               mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                               mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                               )

# %%
cap = cv2.VideoCapture(0)

# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)

        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.42899141,  0.35453895, -0.93933564, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)
np.load('0.npy')
# Out:
# array([ 0.42899141,  0.35453895, -0.93933564, ...,  0.        ,
#         0.        ,  0.        ])

# %%
actions = np.array(['Hello, Namaste, Nama', 'Thanks, Dhanyavad, Dhanyabada', 'Bye, Alvida, Bidaya', 'Please, Kripya, Anugraha', 'Yes, Haan, Hyam', 'No, Nhi, Na'])
DATA_PATH = os.path.join('MP_Data')
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
import os

# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data')

# Actions that we try to detect
actions = np.array(['Hello, Namaste, Nama', 'Thanks, Dhanyavad, Dhanyabada', 'Bye, Alvida, Bidaya', 'Please, Kripya, Anugraha', 'Yes, Haan, Hyam', 'No, Nhi, Na'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 1

for action in actions:
    action_path = os.path.join(DATA_PATH, action)
    
    # Check if the action directory exists, if not, create it
    if not os.path.exists(action_path):
        os.makedirs(action_path)

    dirmax = 0
    
    # Check if the action directory is not empty
    if os.listdir(action_path):
        dirmax = np.max(np.array(os.listdir(action_path)).astype(int))

    for sequence in range(1, no_sequences + 1):
        try:
            os.makedirs(os.path.join(action_path, str(dirmax + sequence)))
        except:
            pass

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}
label_map
# Out:
# {'Hello, Namaste, Nama': 0,
#  'Thanks, Dhanyavad, Dhanyabada': 1,
#  'Bye, Alvida, Bidaya': 2,
#  'Please, Kripya, Anugraha': 3,
#  'Yes, Haan, Hyam': 4,
#  'No, Nhi, Na': 5}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (180, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (180,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (180, 30, 1662)

# %%
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)
y_test.shape
# Out:
# (9, 6)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
from tensorflow.compat.v1 import get_default_graph
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model.fit(X_train, y_train, epochs=500, batch_size=50, callbacks=[tb_callback, early_stopping])
# Out:
# Epoch 1/500
# 4/4 [==============================] - ETA: 0s - loss: 5.5066 - categorical_accuracy: 0.1520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 17s 127ms/step - loss: 5.5066 - categorical_accuracy: 0.1520
# Epoch 2/500
# 4/4 [==============================] - ETA: 0s - loss: 14.3431 - categorical_accuracy: 0.1520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 130ms/step - loss: 14.3431 - categorical_accuracy: 0.1520
# Epoch 3/500
# 4/4 [==============================] - ETA: 0s - loss: 4.5043 - categorical_accuracy: 0.1637WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 138ms/step - loss: 4.5043 - categorical_accuracy: 0.1637
# Epoch 4/500
# 4/4 [==============================] - ETA: 0s - loss: 11.7460 - categorical_accuracy: 0.1579WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 135ms/step - loss: 11.7460 - categorical_accuracy: 0.1579
# Epoch 5/500
# 4/4 [==============================] - ETA: 0s - loss: 7.9800 - categorical_accuracy: 0.1345WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 133ms/step - loss: 7.9800 - categorical_accuracy: 0.1345
# Epoch 6/500
# 4/4 [==============================] - ETA: 0s - loss: 3.4550 - categorical_accuracy: 0.2047WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 126ms/step - loss: 3.4550 - categorical_accuracy: 0.2047
# Epoch 7/500
# 4/4 [==============================] - ETA: 0s - loss: 11.8017 - categorical_accuracy: 0.1696WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 123ms/step - loss: 11.8017 - categorical_accuracy: 0.1696
# Epoch 8/500
# 4/4 [==============================] - ETA: 0s - loss: 18.8249 - categorical_accuracy: 0.1754WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 126ms/step - loss: 18.8249 - categorical_accuracy: 0.1754
# Epoch 9/500
# 4/4 [==============================] - ETA: 0s - loss: 17.7878 - categorical_accuracy: 0.1170WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 140ms/step - loss: 17.7878 - categorical_accuracy: 0.1170
# Epoch 10/500
# 4/4 [==============================] - ETA: 0s - loss: 10.9848 - categorical_accuracy: 0.2339WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 126ms/step - loss: 10.9848 - categorical_accuracy: 0.2339
# Epoch 11/500
# 4/4 [==============================] - ETA: 0s - loss: 12.0834 - categorical_accuracy: 0.1930WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 133ms/step - loss: 12.0834 - categorical_accuracy: 0.1930
# Epoch 12/500
# 4/4 [==============================] - ETA: 0s - loss: 42.2757 - categorical_accuracy: 0.1579WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 123ms/step - loss: 42.2757 - categorical_accuracy: 0.1579
# Epoch 13/500
# 4/4 [==============================] - ETA: 0s - loss: 5.1929 - categorical_accuracy: 0.1930WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 5.1929 - categorical_accuracy: 0.1930
# Epoch 14/500
# 4/4 [==============================] - ETA: 0s - loss: 6.3665 - categorical_accuracy: 0.1813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 100ms/step - loss: 6.3665 - categorical_accuracy: 0.1813
# Epoch 15/500
# 4/4 [==============================] - ETA: 0s - loss: 3.9255 - categorical_accuracy: 0.2047WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 127ms/step - loss: 3.9255 - categorical_accuracy: 0.2047
# Epoch 16/500
# 4/4 [==============================] - ETA: 0s - loss: 4.7444 - categorical_accuracy: 0.2047WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 123ms/step - loss: 4.7444 - categorical_accuracy: 0.2047
# Epoch 17/500
# 4/4 [==============================] - ETA: 0s - loss: 6.3796 - categorical_accuracy: 0.1462WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 130ms/step - loss: 6.3796 - categorical_accuracy: 0.1462
# Epoch 18/500
# 4/4 [==============================] - ETA: 0s - loss: 9.0597 - categorical_accuracy: 0.1754WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 9.0597 - categorical_accuracy: 0.1754
# Epoch 19/500
# 4/4 [==============================] - ETA: 0s - loss: 9.9228 - categorical_accuracy: 0.1754 WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 103ms/step - loss: 9.9228 - categorical_accuracy: 0.1754
# Epoch 20/500
# 4/4 [==============================] - ETA: 0s - loss: 7.8561 - categorical_accuracy: 0.1871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 130ms/step - loss: 7.8561 - categorical_accuracy: 0.1871
# Epoch 21/500
# 4/4 [==============================] - ETA: 0s - loss: 4.8247 - categorical_accuracy: 0.2339WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 127ms/step - loss: 4.8247 - categorical_accuracy: 0.2339
# Epoch 22/500
# 4/4 [==============================] - ETA: 0s - loss: 9.3569 - categorical_accuracy: 0.1579WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 103ms/step - loss: 9.3569 - categorical_accuracy: 0.1579
# Epoch 23/500
# 4/4 [==============================] - ETA: 0s - loss: 5.7635 - categorical_accuracy: 0.1871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 5.7635 - categorical_accuracy: 0.1871
# Epoch 24/500
# 4/4 [==============================] - ETA: 0s - loss: 9.8526 - categorical_accuracy: 0.1871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 130ms/step - loss: 9.8526 - categorical_accuracy: 0.1871
# Epoch 25/500
# 4/4 [==============================] - ETA: 0s - loss: 10.0597 - categorical_accuracy: 0.1754WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 120ms/step - loss: 10.0597 - categorical_accuracy: 0.1754
# Epoch 26/500
# 4/4 [==============================] - ETA: 0s - loss: 5.8878 - categorical_accuracy: 0.1170WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 103ms/step - loss: 5.8878 - categorical_accuracy: 0.1170
# Epoch 27/500
# 4/4 [==============================] - ETA: 0s - loss: 5.3256 - categorical_accuracy: 0.1871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 125ms/step - loss: 5.3256 - categorical_accuracy: 0.1871
# Epoch 28/500
# 4/4 [==============================] - ETA: 0s - loss: 4.6137 - categorical_accuracy: 0.1930WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 4.6137 - categorical_accuracy: 0.1930
# Epoch 29/500
# 4/4 [==============================] - ETA: 0s - loss: 3.6880 - categorical_accuracy: 0.1637WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 115ms/step - loss: 3.6880 - categorical_accuracy: 0.1637
# Epoch 30/500
# 4/4 [==============================] - ETA: 0s - loss: 3.5006 - categorical_accuracy: 0.1754WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 3.5006 - categorical_accuracy: 0.1754
# Epoch 31/500
# 4/4 [==============================] - ETA: 0s - loss: 3.1115 - categorical_accuracy: 0.1813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 3.1115 - categorical_accuracy: 0.1813
# Epoch 32/500
# 4/4 [==============================] - ETA: 0s - loss: 2.7226 - categorical_accuracy: 0.1404WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 123ms/step - loss: 2.7226 - categorical_accuracy: 0.1404
# Epoch 33/500
# 4/4 [==============================] - ETA: 0s - loss: 2.5993 - categorical_accuracy: 0.1520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 110ms/step - loss: 2.5993 - categorical_accuracy: 0.1520
# Epoch 34/500
# 4/4 [==============================] - ETA: 0s - loss: 4.1428 - categorical_accuracy: 0.1871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 130ms/step - loss: 4.1428 - categorical_accuracy: 0.1871
# Epoch 35/500
# 4/4 [==============================] - ETA: 0s - loss: 2.4563 - categorical_accuracy: 0.1988WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 107ms/step - loss: 2.4563 - categorical_accuracy: 0.1988
# Epoch 36/500
# 4/4 [==============================] - ETA: 0s - loss: 2.4203 - categorical_accuracy: 0.1813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 126ms/step - loss: 2.4203 - categorical_accuracy: 0.1813
# Epoch 37/500
# 4/4 [==============================] - ETA: 0s - loss: 2.2826 - categorical_accuracy: 0.1813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 108ms/step - loss: 2.2826 - categorical_accuracy: 0.1813
# Epoch 38/500
# 4/4 [==============================] - ETA: 0s - loss: 2.2204 - categorical_accuracy: 0.2456WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 132ms/step - loss: 2.2204 - categorical_accuracy: 0.2456
# Epoch 39/500
# 4/4 [==============================] - ETA: 0s - loss: 2.0346 - categorical_accuracy: 0.1637WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 107ms/step - loss: 2.0346 - categorical_accuracy: 0.1637
# Epoch 40/500
# 4/4 [==============================] - ETA: 0s - loss: 2.1831 - categorical_accuracy: 0.1462WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 118ms/step - loss: 2.1831 - categorical_accuracy: 0.1462
# Epoch 41/500
# 4/4 [==============================] - ETA: 0s - loss: 2.2561 - categorical_accuracy: 0.1520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 2.2561 - categorical_accuracy: 0.1520
# Epoch 42/500
# 4/4 [==============================] - ETA: 0s - loss: 2.2237 - categorical_accuracy: 0.1930WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 123ms/step - loss: 2.2237 - categorical_accuracy: 0.1930
# Epoch 43/500
# 4/4 [==============================] - ETA: 0s - loss: 2.0046 - categorical_accuracy: 0.1637WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 119ms/step - loss: 2.0046 - categorical_accuracy: 0.1637
# Epoch 44/500
# 4/4 [==============================] - ETA: 0s - loss: 1.8650 - categorical_accuracy: 0.1930WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 123ms/step - loss: 1.8650 - categorical_accuracy: 0.1930
# Epoch 45/500
# 4/4 [==============================] - ETA: 0s - loss: 1.8511 - categorical_accuracy: 0.2281WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.8511 - categorical_accuracy: 0.2281
# Epoch 46/500
# 4/4 [==============================] - ETA: 0s - loss: 1.8104 - categorical_accuracy: 0.2632WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 96ms/step - loss: 1.8104 - categorical_accuracy: 0.2632
# Epoch 47/500
# 4/4 [==============================] - ETA: 0s - loss: 1.8065 - categorical_accuracy: 0.2398WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.8065 - categorical_accuracy: 0.2398
# Epoch 48/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7994 - categorical_accuracy: 0.2632WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.7994 - categorical_accuracy: 0.2632
# Epoch 49/500
# 4/4 [==============================] - ETA: 0s - loss: 1.9292 - categorical_accuracy: 0.1930WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 1.9292 - categorical_accuracy: 0.1930
# Epoch 50/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7958 - categorical_accuracy: 0.2398WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 115ms/step - loss: 1.7958 - categorical_accuracy: 0.2398
# Epoch 51/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7777 - categorical_accuracy: 0.2573WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 127ms/step - loss: 1.7777 - categorical_accuracy: 0.2573
# Epoch 52/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7487 - categorical_accuracy: 0.1930WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.7487 - categorical_accuracy: 0.1930
# Epoch 53/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7687 - categorical_accuracy: 0.2456WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.7687 - categorical_accuracy: 0.2456
# Epoch 54/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6884 - categorical_accuracy: 0.3099WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.6884 - categorical_accuracy: 0.3099
# Epoch 55/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6094 - categorical_accuracy: 0.3450WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.6094 - categorical_accuracy: 0.3450
# Epoch 56/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5623 - categorical_accuracy: 0.4152WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.5623 - categorical_accuracy: 0.4152
# Epoch 57/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4814 - categorical_accuracy: 0.4035WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 1.4814 - categorical_accuracy: 0.4035
# Epoch 58/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6255 - categorical_accuracy: 0.3041WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.6255 - categorical_accuracy: 0.3041
# Epoch 59/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5456 - categorical_accuracy: 0.3450WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.5456 - categorical_accuracy: 0.3450
# Epoch 60/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5254 - categorical_accuracy: 0.3977WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.5254 - categorical_accuracy: 0.3977
# Epoch 61/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5380 - categorical_accuracy: 0.3626WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.5380 - categorical_accuracy: 0.3626
# Epoch 62/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4958 - categorical_accuracy: 0.4152WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.4958 - categorical_accuracy: 0.4152
# Epoch 63/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4528 - categorical_accuracy: 0.4152WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.4528 - categorical_accuracy: 0.4152
# Epoch 64/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4026 - categorical_accuracy: 0.4269WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.4026 - categorical_accuracy: 0.4269
# Epoch 65/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3916 - categorical_accuracy: 0.4327WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 115ms/step - loss: 1.3916 - categorical_accuracy: 0.4327
# Epoch 66/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3392 - categorical_accuracy: 0.4737WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 119ms/step - loss: 1.3392 - categorical_accuracy: 0.4737
# Epoch 67/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4406 - categorical_accuracy: 0.4152WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.4406 - categorical_accuracy: 0.4152
# Epoch 68/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3481 - categorical_accuracy: 0.4503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.3481 - categorical_accuracy: 0.4503
# Epoch 69/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3452 - categorical_accuracy: 0.4561WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.3452 - categorical_accuracy: 0.4561
# Epoch 70/500
# 4/4 [==============================] - ETA: 0s - loss: 1.2879 - categorical_accuracy: 0.5263WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 110ms/step - loss: 1.2879 - categorical_accuracy: 0.5263
# Epoch 71/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3172 - categorical_accuracy: 0.4678WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.3172 - categorical_accuracy: 0.4678
# Epoch 72/500
# 4/4 [==============================] - ETA: 0s - loss: 1.2954 - categorical_accuracy: 0.4503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.2954 - categorical_accuracy: 0.4503
# Epoch 73/500
# 4/4 [==============================] - ETA: 0s - loss: 1.2318 - categorical_accuracy: 0.5497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.2318 - categorical_accuracy: 0.5497
# Epoch 74/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3399 - categorical_accuracy: 0.4620WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.3399 - categorical_accuracy: 0.4620
# Epoch 75/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3748 - categorical_accuracy: 0.4094WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.3748 - categorical_accuracy: 0.4094
# Epoch 76/500
# 4/4 [==============================] - ETA: 0s - loss: 1.9574 - categorical_accuracy: 0.2749WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 115ms/step - loss: 1.9574 - categorical_accuracy: 0.2749
# Epoch 77/500
# 4/4 [==============================] - ETA: 0s - loss: 2.2301 - categorical_accuracy: 0.2105WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 2.2301 - categorical_accuracy: 0.2105
# Epoch 78/500
# 4/4 [==============================] - ETA: 0s - loss: 1.9779 - categorical_accuracy: 0.2398WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.9779 - categorical_accuracy: 0.2398
# Epoch 79/500
# 4/4 [==============================] - ETA: 0s - loss: 2.0492 - categorical_accuracy: 0.1988WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 2.0492 - categorical_accuracy: 0.1988
# Epoch 80/500
# 4/4 [==============================] - ETA: 0s - loss: 1.9180 - categorical_accuracy: 0.1696WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.9180 - categorical_accuracy: 0.1696
# Epoch 81/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7536 - categorical_accuracy: 0.2807WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 114ms/step - loss: 1.7536 - categorical_accuracy: 0.2807
# Epoch 82/500
# 4/4 [==============================] - ETA: 0s - loss: 1.8197 - categorical_accuracy: 0.2632WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.8197 - categorical_accuracy: 0.2632
# Epoch 83/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7171 - categorical_accuracy: 0.2164WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.7171 - categorical_accuracy: 0.2164
# Epoch 84/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7012 - categorical_accuracy: 0.2865WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 1.7012 - categorical_accuracy: 0.2865
# Epoch 85/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6587 - categorical_accuracy: 0.2982WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.6587 - categorical_accuracy: 0.2982
# Epoch 86/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6304 - categorical_accuracy: 0.2749WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.6304 - categorical_accuracy: 0.2749
# Epoch 87/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5985 - categorical_accuracy: 0.2456WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.5985 - categorical_accuracy: 0.2456
# Epoch 88/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5527 - categorical_accuracy: 0.3275WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.5527 - categorical_accuracy: 0.3275
# Epoch 89/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5908 - categorical_accuracy: 0.3392WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.5908 - categorical_accuracy: 0.3392
# Epoch 90/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5212 - categorical_accuracy: 0.3450WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 114ms/step - loss: 1.5212 - categorical_accuracy: 0.3450
# Epoch 91/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5056 - categorical_accuracy: 0.3275WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.5056 - categorical_accuracy: 0.3275
# Epoch 92/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5358 - categorical_accuracy: 0.3860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.5358 - categorical_accuracy: 0.3860
# Epoch 93/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5032 - categorical_accuracy: 0.3041WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.5032 - categorical_accuracy: 0.3041
# Epoch 94/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4671 - categorical_accuracy: 0.3158WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.4671 - categorical_accuracy: 0.3158
# Epoch 95/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4731 - categorical_accuracy: 0.3509WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 114ms/step - loss: 1.4731 - categorical_accuracy: 0.3509
# Epoch 96/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4042 - categorical_accuracy: 0.4152WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.4042 - categorical_accuracy: 0.4152
# Epoch 97/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3815 - categorical_accuracy: 0.3626WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.3815 - categorical_accuracy: 0.3626
# Epoch 98/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3759 - categorical_accuracy: 0.3567WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.3759 - categorical_accuracy: 0.3567
# Epoch 99/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3426 - categorical_accuracy: 0.4211WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.3426 - categorical_accuracy: 0.4211
# Epoch 100/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3305 - categorical_accuracy: 0.4211WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.3305 - categorical_accuracy: 0.4211
# Epoch 101/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3339 - categorical_accuracy: 0.3977WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 118ms/step - loss: 1.3339 - categorical_accuracy: 0.3977
# Epoch 102/500
# 4/4 [==============================] - ETA: 0s - loss: 1.9602 - categorical_accuracy: 0.2222WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 119ms/step - loss: 1.9602 - categorical_accuracy: 0.2222
# Epoch 103/500
# 4/4 [==============================] - ETA: 0s - loss: 1.9385 - categorical_accuracy: 0.2281WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.9385 - categorical_accuracy: 0.2281
# Epoch 104/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7039 - categorical_accuracy: 0.3099WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 1.7039 - categorical_accuracy: 0.3099
# Epoch 105/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7057 - categorical_accuracy: 0.2690WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.7057 - categorical_accuracy: 0.2690
# Epoch 106/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6238 - categorical_accuracy: 0.2924WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.6238 - categorical_accuracy: 0.2924
# Epoch 107/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6138 - categorical_accuracy: 0.3333WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.6138 - categorical_accuracy: 0.3333
# Epoch 108/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5869 - categorical_accuracy: 0.3743WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 123ms/step - loss: 1.5869 - categorical_accuracy: 0.3743
# Epoch 109/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5569 - categorical_accuracy: 0.3275WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 123ms/step - loss: 1.5569 - categorical_accuracy: 0.3275
# Epoch 110/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5903 - categorical_accuracy: 0.3158WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 110ms/step - loss: 1.5903 - categorical_accuracy: 0.3158
# Epoch 111/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4962 - categorical_accuracy: 0.3918WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 118ms/step - loss: 1.4962 - categorical_accuracy: 0.3918
# Epoch 112/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4501 - categorical_accuracy: 0.3743WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 110ms/step - loss: 1.4501 - categorical_accuracy: 0.3743
# Epoch 113/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4895 - categorical_accuracy: 0.3860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.4895 - categorical_accuracy: 0.3860
# Epoch 114/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4803 - categorical_accuracy: 0.3860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 1.4803 - categorical_accuracy: 0.3860
# Epoch 115/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4086 - categorical_accuracy: 0.3977WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.4086 - categorical_accuracy: 0.3977
# Epoch 116/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4195 - categorical_accuracy: 0.3918WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.4195 - categorical_accuracy: 0.3918
# Epoch 117/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3843 - categorical_accuracy: 0.4327WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.3843 - categorical_accuracy: 0.4327
# Epoch 118/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3698 - categorical_accuracy: 0.4152WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.3698 - categorical_accuracy: 0.4152
# Epoch 119/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3512 - categorical_accuracy: 0.4211WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.3512 - categorical_accuracy: 0.4211
# Epoch 120/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3341 - categorical_accuracy: 0.4503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.3341 - categorical_accuracy: 0.4503
# Epoch 121/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3686 - categorical_accuracy: 0.4152WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.3686 - categorical_accuracy: 0.4152
# Epoch 122/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4700 - categorical_accuracy: 0.3977WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 110ms/step - loss: 1.4700 - categorical_accuracy: 0.3977
# Epoch 123/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6704 - categorical_accuracy: 0.3216WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.6704 - categorical_accuracy: 0.3216
# Epoch 124/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6586 - categorical_accuracy: 0.3158WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.6586 - categorical_accuracy: 0.3158
# Epoch 125/500
# 4/4 [==============================] - ETA: 0s - loss: 1.7142 - categorical_accuracy: 0.2865WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 1.7142 - categorical_accuracy: 0.2865
# Epoch 126/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6308 - categorical_accuracy: 0.3333WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 1.6308 - categorical_accuracy: 0.3333
# Epoch 127/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6498 - categorical_accuracy: 0.3099WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 130ms/step - loss: 1.6498 - categorical_accuracy: 0.3099
# Epoch 128/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5066 - categorical_accuracy: 0.3801WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 103ms/step - loss: 1.5066 - categorical_accuracy: 0.3801
# Epoch 129/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4312 - categorical_accuracy: 0.4269WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 1.4312 - categorical_accuracy: 0.4269
# Epoch 130/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4522 - categorical_accuracy: 0.4503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 118ms/step - loss: 1.4522 - categorical_accuracy: 0.4503
# Epoch 131/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4264 - categorical_accuracy: 0.3977WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.4264 - categorical_accuracy: 0.3977
# Epoch 132/500
# 4/4 [==============================] - ETA: 0s - loss: 1.4314 - categorical_accuracy: 0.3918WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 115ms/step - loss: 1.4314 - categorical_accuracy: 0.3918
# Epoch 133/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3832 - categorical_accuracy: 0.4035WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.3832 - categorical_accuracy: 0.4035
# Epoch 134/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3900 - categorical_accuracy: 0.4211WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.3900 - categorical_accuracy: 0.4211
# Epoch 135/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3669 - categorical_accuracy: 0.3684WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.3669 - categorical_accuracy: 0.3684
# Epoch 136/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3594 - categorical_accuracy: 0.4211WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.3594 - categorical_accuracy: 0.4211
# Epoch 137/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3458 - categorical_accuracy: 0.4444WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 119ms/step - loss: 1.3458 - categorical_accuracy: 0.4444
# Epoch 138/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3549 - categorical_accuracy: 0.3860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 1.3549 - categorical_accuracy: 0.3860
# Epoch 139/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3087 - categorical_accuracy: 0.4444WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 107ms/step - loss: 1.3087 - categorical_accuracy: 0.4444
# Epoch 140/500
# ...
# 4/4 [==============================] - 1s 133ms/step - loss: 1.0559 - categorical_accuracy: 0.5965
# Epoch 455/500
# 4/4 [==============================] - ETA: 0s - loss: 0.8450 - categorical_accuracy: 0.6374WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 110ms/step - loss: 0.8450 - categorical_accuracy: 0.6374
# Epoch 456/500
# 4/4 [==============================] - ETA: 0s - loss: 0.8579 - categorical_accuracy: 0.6316WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 116ms/step - loss: 0.8579 - categorical_accuracy: 0.6316
# Epoch 457/500
# 4/4 [==============================] - ETA: 0s - loss: 0.8156 - categorical_accuracy: 0.6082WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 140ms/step - loss: 0.8156 - categorical_accuracy: 0.6082
# Epoch 458/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6837 - categorical_accuracy: 0.6901WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 110ms/step - loss: 0.6837 - categorical_accuracy: 0.6901
# Epoch 459/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6071 - categorical_accuracy: 0.7076WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 134ms/step - loss: 0.6071 - categorical_accuracy: 0.7076
# Epoch 460/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6529 - categorical_accuracy: 0.6784WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 103ms/step - loss: 0.6529 - categorical_accuracy: 0.6784
# Epoch 461/500
# 4/4 [==============================] - ETA: 0s - loss: 0.7476 - categorical_accuracy: 0.6374WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 143ms/step - loss: 0.7476 - categorical_accuracy: 0.6374
# Epoch 462/500
# 4/4 [==============================] - ETA: 0s - loss: 0.7565 - categorical_accuracy: 0.6550WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 103ms/step - loss: 0.7565 - categorical_accuracy: 0.6550
# Epoch 463/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6535 - categorical_accuracy: 0.7076WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 132ms/step - loss: 0.6535 - categorical_accuracy: 0.7076
# Epoch 464/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6498 - categorical_accuracy: 0.7251WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 0.6498 - categorical_accuracy: 0.7251
# Epoch 465/500
# 4/4 [==============================] - ETA: 0s - loss: 0.7392 - categorical_accuracy: 0.6199WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 0.7392 - categorical_accuracy: 0.6199
# Epoch 466/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6965 - categorical_accuracy: 0.7018WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 126ms/step - loss: 0.6965 - categorical_accuracy: 0.7018
# Epoch 467/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6930 - categorical_accuracy: 0.7310WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 110ms/step - loss: 0.6930 - categorical_accuracy: 0.7310
# Epoch 468/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6090 - categorical_accuracy: 0.6901WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 127ms/step - loss: 0.6090 - categorical_accuracy: 0.6901
# Epoch 469/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6746 - categorical_accuracy: 0.6257WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 0.6746 - categorical_accuracy: 0.6257
# Epoch 470/500
# 4/4 [==============================] - ETA: 0s - loss: 0.5380 - categorical_accuracy: 0.7427WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 107ms/step - loss: 0.5380 - categorical_accuracy: 0.7427
# Epoch 471/500
# 4/4 [==============================] - ETA: 0s - loss: 0.5349 - categorical_accuracy: 0.7719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 126ms/step - loss: 0.5349 - categorical_accuracy: 0.7719
# Epoch 472/500
# 4/4 [==============================] - ETA: 0s - loss: 0.5491 - categorical_accuracy: 0.7076WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 123ms/step - loss: 0.5491 - categorical_accuracy: 0.7076
# Epoch 473/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6000 - categorical_accuracy: 0.7310WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 123ms/step - loss: 0.6000 - categorical_accuracy: 0.7310
# Epoch 474/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6475 - categorical_accuracy: 0.6901WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 0.6475 - categorical_accuracy: 0.6901
# Epoch 475/500
# 4/4 [==============================] - ETA: 0s - loss: 0.5748 - categorical_accuracy: 0.7661WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 117ms/step - loss: 0.5748 - categorical_accuracy: 0.7661
# Epoch 476/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6270 - categorical_accuracy: 0.7251WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 0.6270 - categorical_accuracy: 0.7251
# Epoch 477/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6396 - categorical_accuracy: 0.6608WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 111ms/step - loss: 0.6396 - categorical_accuracy: 0.6608
# Epoch 478/500
# 4/4 [==============================] - ETA: 0s - loss: 0.5991 - categorical_accuracy: 0.7135WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 115ms/step - loss: 0.5991 - categorical_accuracy: 0.7135
# Epoch 479/500
# 4/4 [==============================] - ETA: 0s - loss: 0.5104 - categorical_accuracy: 0.7661WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 123ms/step - loss: 0.5104 - categorical_accuracy: 0.7661
# Epoch 480/500
# 4/4 [==============================] - ETA: 0s - loss: 0.5749 - categorical_accuracy: 0.7076WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 127ms/step - loss: 0.5749 - categorical_accuracy: 0.7076
# Epoch 481/500
# 4/4 [==============================] - ETA: 0s - loss: 0.5229 - categorical_accuracy: 0.7368WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 0.5229 - categorical_accuracy: 0.7368
# Epoch 482/500
# 4/4 [==============================] - ETA: 0s - loss: 0.5380 - categorical_accuracy: 0.7778WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 113ms/step - loss: 0.5380 - categorical_accuracy: 0.7778
# Epoch 483/500
# 4/4 [==============================] - ETA: 0s - loss: 0.4975 - categorical_accuracy: 0.7719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 118ms/step - loss: 0.4975 - categorical_accuracy: 0.7719
# Epoch 484/500
# 4/4 [==============================] - ETA: 0s - loss: 0.5095 - categorical_accuracy: 0.7719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 137ms/step - loss: 0.5095 - categorical_accuracy: 0.7719
# Epoch 485/500
# 4/4 [==============================] - ETA: 0s - loss: 0.4942 - categorical_accuracy: 0.7836WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 106ms/step - loss: 0.4942 - categorical_accuracy: 0.7836
# Epoch 486/500
# 4/4 [==============================] - ETA: 0s - loss: 0.4897 - categorical_accuracy: 0.8129WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 133ms/step - loss: 0.4897 - categorical_accuracy: 0.8129
# Epoch 487/500
# 4/4 [==============================] - ETA: 0s - loss: 0.6056 - categorical_accuracy: 0.7544WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 126ms/step - loss: 0.6056 - categorical_accuracy: 0.7544
# Epoch 488/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6634 - categorical_accuracy: 0.4561WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 103ms/step - loss: 1.6634 - categorical_accuracy: 0.4561
# Epoch 489/500
# 4/4 [==============================] - ETA: 0s - loss: 0.8832 - categorical_accuracy: 0.6199WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 132ms/step - loss: 0.8832 - categorical_accuracy: 0.6199
# Epoch 490/500
# 4/4 [==============================] - ETA: 0s - loss: 1.6539 - categorical_accuracy: 0.4503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 113ms/step - loss: 1.6539 - categorical_accuracy: 0.4503
# Epoch 491/500
# 4/4 [==============================] - ETA: 0s - loss: 1.5233 - categorical_accuracy: 0.3918WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 140ms/step - loss: 1.5233 - categorical_accuracy: 0.3918
# Epoch 492/500
# 4/4 [==============================] - ETA: 0s - loss: 1.2936 - categorical_accuracy: 0.4561WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 121ms/step - loss: 1.2936 - categorical_accuracy: 0.4561
# Epoch 493/500
# 4/4 [==============================] - ETA: 0s - loss: 1.2645 - categorical_accuracy: 0.4269WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 105ms/step - loss: 1.2645 - categorical_accuracy: 0.4269
# Epoch 494/500
# 4/4 [==============================] - ETA: 0s - loss: 1.3961 - categorical_accuracy: 0.4094WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 130ms/step - loss: 1.3961 - categorical_accuracy: 0.4094
# Epoch 495/500
# 4/4 [==============================] - ETA: 0s - loss: 1.1837 - categorical_accuracy: 0.4620WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 134ms/step - loss: 1.1837 - categorical_accuracy: 0.4620
# Epoch 496/500
# 4/4 [==============================] - ETA: 0s - loss: 1.1338 - categorical_accuracy: 0.4737WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 107ms/step - loss: 1.1338 - categorical_accuracy: 0.4737
# Epoch 497/500
# 4/4 [==============================] - ETA: 0s - loss: 1.1664 - categorical_accuracy: 0.4561WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 130ms/step - loss: 1.1664 - categorical_accuracy: 0.4561
# Epoch 498/500
# 4/4 [==============================] - ETA: 0s - loss: 1.0253 - categorical_accuracy: 0.4795WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 107ms/step - loss: 1.0253 - categorical_accuracy: 0.4795
# Epoch 499/500
# 4/4 [==============================] - ETA: 0s - loss: 1.0420 - categorical_accuracy: 0.4327WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 0s 120ms/step - loss: 1.0420 - categorical_accuracy: 0.4327
# Epoch 500/500
# 4/4 [==============================] - ETA: 0s - loss: 0.9708 - categorical_accuracy: 0.4854WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 4/4 [==============================] - 1s 122ms/step - loss: 0.9708 - categorical_accuracy: 0.4854

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 30, 64)            442112
#
#  lstm_4 (LSTM)               (None, 30, 128)           98816
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dense_11 (Dense)            (None, 6)                 198
#
# =================================================================
# Total params: 596774 (2.28 MB)
# Trainable params: 596774 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
actions[np.argmax(res[4])]
# Out:
# 'Hello, Namaste, Nama'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'Hello, Namaste, Nama'

# %%
model.save('action.keras')

# %%
from keras.models import load_model
model = load_model('action.keras')

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[8, 0],
#         [0, 1]],
#
#        [[5, 0],
#         [3, 1]],
#
#        [[7, 2],
#         [0, 0]],
#
#        [[6, 3],
#         [0, 0]],
#
#        [[6, 1],
#         [1, 1]],
#
#        [[7, 0],
#         [2, 0]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.3333333333333333

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]

def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()

    # Ensure all lists have the same length
    min_length = min(len(res), len(actions), len(colors))
    res = res[:min_length]
    actions = actions[:min_length]
    colors = colors[:min_length]
    
    for num, prob in enumerate(res):
        if isinstance(prob, (int, float)):
            class_prob = prob  # It's a scalar, use it directly
        elif isinstance(prob, (list, np.ndarray)) and len(prob) > 0:
            class_prob = prob[0]  # It's an array, use the first element
        else:
            class_prob = 0  # Default to 0 if prob is not a valid iterable

        width = int(class_prob * 100)  # Adjust the scale as needed
        cv2.rectangle(output_frame, (0, 60 + num * 40), (width, 90 + num * 40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85 + num * 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2,
                    cv2.LINE_AA)

    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))

# %%
# # 1. New detection variables
# sequence = []
# sentence = []
# predictions = []
# threshold = 0.5

# cap = cv2.VideoCapture(0)
# # Set mediapipe model 
# with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#     while cap.isOpened():

#         # Read feed
#         ret, frame = cap.read()

#         # Make detections
#         image, results = mediapipe_detection(frame, holistic)
#         print(results)
        
#         # Draw landmarks
#         draw_styled_landmarks(image, results)
        
#         # 2. Prediction logic
#         keypoints = extract_keypoints(results)
#         sequence.append(keypoints)
#         sequence = sequence[-30:]
        
#         if len(sequence) == 30:
#             res = model.predict(np.expand_dims(sequence, axis=0))[0]
#             print(actions[np.argmax(res)])
#             predictions.append(np.argmax(res))
            
            
#         #3. Viz logic
#             if np.unique(predictions[-10:])[0]==np.argmax(res): 
#                 if res[np.argmax(res)] > threshold: 
                    
#                     if len(sentence) > 0: 
#                         if actions[np.argmax(res)] != sentence[-1]:
#                             sentence.append(actions[np.argmax(res)])
#                     else:
#                         sentence.append(actions[np.argmax(res)])

#             if len(sentence) > 5: 
#                 sentence = sentence[-5:]

#             # Viz probabilities
#             image = prob_viz(res, actions, image, colors)
            
#         cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
#         cv2.putText(image, ' '.join(sentence), (3,30), 
#                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
#         # Show to screen
#         cv2.imshow('OpenCV Feed', image)

#         # Break gracefully
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break
#     cap.release()
#     cv2.destroyAllWindows()

sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()
        image, results = mediapipe_detection(frame, holistic)
        draw_styled_landmarks(image, results)
        
        sequence.append(extract_keypoints(results))
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predictions.append(np.argmax(res))
            
            sentence = [actions[np.argmax(res)]] if np.unique(predictions[-10:])[0] == np.argmax(res) and res[np.argmax(res)] > threshold else sentence[-4:]

            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step

# %%
input('Press Enter')
